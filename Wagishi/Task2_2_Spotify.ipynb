# %% [markdown]
# # Installing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
song = pd.read_csv('spotify-2023.csv' , encoding='latin-1')

# %%
song.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# Handling missing values

# %%
song.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
song.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
song['streams']=song['streams'].fillna(0)
song['in_shazam_charts'] = song['in_shazam_charts'].fillna(0)
song['key'] = song['key'].fillna('unknown')
song.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %% [markdown]
# Changing the data type

# %%
song['streams'] = pd.to_numeric(song['streams'], errors='coerce')
song['in_deezer_playlists'] = pd.to_numeric(song['in_deezer_playlists'], errors='coerce')
song['in_shazam_charts'] = pd.to_numeric(song['in_shazam_charts'], errors='coerce')

# %%
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               952 non-null    float64
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   874 non-null    float64
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      946 non-null    float64
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# Encoding the data

# %%
song['mode'].value_counts()
# Out:
# mode
# Major    550
# Minor    403
# Name: count, dtype: int64

# %%
song['key'].value_counts()
# Out:
# key
# C#         120
# G           96
# unknown     95
# G#          91
# F           89
# B           81
# D           81
# A           75
# F#          73
# E           62
# A#          57
# D#          33
# Name: count, dtype: int64

# %%
song_encoded = pd.get_dummies(song, columns=['key', 'mode'], drop_first=True)

# %%
song_encoded.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts      streams  in_apple_playlists  ...  key_C#  key_D  \
# ...

# %%
correlation_matrix = song_encoded.corr(numeric_only=True)
plt.figure(figsize=(18, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# By observing the matrix , we can conclude that there is no need of encoding the data And
#
# ---
#
#
# 1.Spotify_playlist high correlate to deezer,apple playlist and streams
#
# ---
#
#
# 2.Spotify_charts highly correlate to deezer,apple,shazam charts
#
#
# ---
#
#
#
# 3.Stream correlate with apple and deezer playlist
#
#
# ---
#
#
# 4.Apple playlist correlate with deezer playlist

# %%
song['artist(s)_name'].value_counts()
# Out:
# artist(s)_name
# Taylor Swift                          34
# The Weeknd                            22
# SZA                                   19
# Bad Bunny                             19
# Harry Styles                          17
#                                       ..
# Gorillaz, Bad Bunny                    1
# j-hope, J. Cole                        1
# Robin Schulz, Oliver Tree              1
# Don Toliver, Future, Justin Bieber     1
# The Walters                            1
# Name: count, Length: 645, dtype: int64

# %%
top_artists = song.groupby('artist(s)_name')['streams'].sum().sort_values(ascending=False).head(20)
plt.figure(figsize=(12, 6))
sns.barplot(y=top_artists.index, x=top_artists.values, palette='viridis')
plt.ylabel('Artist Name')
plt.xlabel('Total Streams (in billions)')
plt.title('Top 20 Artists by Total Streams')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=song['in_spotify_playlists'],y=song['streams'])
plt.xlabel('in_spotify_playlists')
plt.ylabel('streams')
plt.title('Scatter Plot of in_spotify_playlists vs streams')
plt.show

plt.figure(figsize=(5,5))
sns.scatterplot(x=song['in_apple_playlists'],y=song['streams'])
plt.xlabel('in_apple_playlists')
plt.ylabel('streams')
plt.title('Scatter Plot of in_apple_playlists vs streams')
plt.show

plt.figure(figsize=(5,5))
sns.scatterplot(x=song['in_deezer_playlists'],y=song['streams'])
plt.xlabel('in_deezer_playlists')
plt.ylabel('streams')
plt.title('Scatter Plot of in_deezer_playlists vs streams')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# model fitting

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
x=song_encoded.drop(columns=['streams','track_name','artist(s)_name'],axis=1)
y=song_encoded["streams"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Remove redundant LinearRegression initialization
lr=LinearRegression()

# %%
# Check for and handle infinite values in x_train and y_train
import numpy as np

# Identify rows with NaN or infinite values in x_train or y_train
finite_mask = np.isfinite(x_train).all(axis=1) & np.isfinite(y_train)

# Filter out rows with non-finite values
x_train = x_train[finite_mask]
y_train = y_train[finite_mask]

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Fill missing values in x_test with the mean of the test set
x_test = x_test.fillna(x_test.mean())

y_pred = lr.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 8.61212753854589e+16
# R-squared: 0.682124935595712

# %%
test_indices = x_test.index
test_songs = song.loc[test_indices]

predictions_df = pd.DataFrame({
    'artist(s)_name': test_songs['artist(s)_name'],
    'track_name': test_songs['track_name'],
    'predicted_streams': y_pred
})
