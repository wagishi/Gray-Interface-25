# %%
import numpy as np
import os
import pandas as pd
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchmetrics import Accuracy
import random
from tqdm.auto import tqdm
from timeit import default_timer as timer


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
IMAGE_SIZE = (64, 64)  # Setting image size to 64*64, default is 224*224

# Define transform to resize and convert to tensor
transform = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor()
])

# Load the dataset
# Replace with your dataset directory
dataset_path = r"C:\archive\imagenet100\train"
dataset = datasets.ImageFolder(root=dataset_path, transform=transform)

# Create the DataLoader
loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=4)

# Initialize mean and std
mean = 0.0
std = 0.0
total_images_count = 0

# Compute mean and std over the entire dataset
print("Calculating mean and std...")
for images, _ in loader:
    batch_samples = images.size(0)  # batch size (last batch can have smaller size!)
    images = images.view(batch_samples, images.size(1), -1)  # reshape to (B, C, H*W)
    
    mean += images.mean(2).sum(0)
    std += images.std(2).sum(0)
    total_images_count += batch_samples

mean /= total_images_count
std /= total_images_count

print(f"Mean: {mean}")
print(f"Std: {std}")
# Out:
# Calculating mean and std...
# Mean: tensor([0.4531, 0.4513, 0.3910])
# Std: tensor([0.1808, 0.1760, 0.1748])

# %%
# Define transforms for train_dataset
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

# Define transforms for val_dataset
val_transforms = transforms.Compose([
    transforms.Resize((64,64)),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

# %%
train_dataset = ImageFolder(r"C:\archive\imagenet100\train",transform= train_transforms)
val_dataset = ImageFolder(r"C:\archive\val.X", transform= val_transforms)

train_loader= DataLoader(train_dataset,batch_size=128,shuffle=True,num_workers=4)
val_loader= DataLoader(val_dataset,batch_size=128,shuffle=False,num_workers=4)

# %%
def save_epoch_metrics_csv(model_name, train_loss_history, val_loss_history,
                           train_acc_history, val_top1_acc_history, val_top5_acc_history,
                           filename=None):
    metrics_dict = {
        "epoch": list(range(1, len(train_loss_history) + 1)),
        "train_loss": train_loss_history,
        "val_loss": val_loss_history,
        "train_acc": train_acc_history,
        "val_top1": val_top1_acc_history,
        "val_top5": val_top5_acc_history,
    }
    df = pd.DataFrame(metrics_dict)

    if filename is None:
        filename = f"results/per_model_logs/{model_name}_metrics.csv"
    # Ensure directory exists
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    df.to_csv(filename, index=False)
    print(f"[✓] Saved epoch metrics to {filename}")


def append_model_summary(model_name, train_loss_history, val_loss_history,
                         train_acc_history, val_top1_acc_history, val_top5_acc_history,
                         total_train_time_sec, model, batch_size, optimizer_type,
                         lr_schedule_desc, image_size, architecture_type,
                         summary_csv_path="results/summary/final_model_comparison.csv"):

    num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    summary_dict = {
        "model_name": model_name,
        "final_train_loss": train_loss_history[-1],
        "final_val_loss": val_loss_history[-1],
        "final_train_acc": train_acc_history[-1],
        "final_val_top1_acc": val_top1_acc_history[-1],
        "final_val_top5_acc": val_top5_acc_history[-1],
        "total_train_time_sec": total_train_time_sec,
        "total_train_time_min": round(total_train_time_sec / 60, 2),
        "num_params": num_params,
        "batch_size": batch_size,
        "optimizer": optimizer_type,
        "learning_rate_schedule": lr_schedule_desc,
        "image_size": image_size,
        "architecture_type": architecture_type,
    }

    # Ensure output directory exists
    os.makedirs(os.path.dirname(summary_csv_path), exist_ok=True)

    # Append or create
    if os.path.exists(summary_csv_path):
        existing_df = pd.read_csv(summary_csv_path)
        updated_df = pd.concat([existing_df, pd.DataFrame([summary_dict])], ignore_index=True)
    else:
        updated_df = pd.DataFrame([summary_dict])

    updated_df.to_csv(summary_csv_path, index=False)
    print(f"[✓] Appended model summary to {summary_csv_path}")

# %%
# Analyzing time taken to train the model
def print_train_time(start: float,
                     end: float,
                     device: torch.device = None):
  total_time = end-start
  print(f"Train time on {device} : {total_time:.3f} seconds")
  return total_time

# %%
def train_model(
    model,
    train_loader,
    val_loader,
    loss_fn,
    optimizer_adam,
    optimizer_sgd,
    scheduler_adam,
    scheduler_sgd,
    epochs,
    batch_size,
    image_size,
    architecture_type,
    model_name
):
    # Track metrics
    train_loss_history, val_loss_history = [], []
    train_acc_history, val_top1_acc_history, val_top5_acc_history = [], [], []

    best_top1 = 0.0
    best_model_wts = None

    start_time = timer()

    for epoch in tqdm(range(epochs)):
        print(f"\nEpoch {epoch+1}/{epochs}\n{'-'*20}")

        # ----------------
        # Select optimizer
        # ----------------
        if epoch < 30:
            optimizer = optimizer_adam
            scheduler = scheduler_adam
        else:
            optimizer = optimizer_sgd
            scheduler = scheduler_sgd

        # ----------------
        # Training Phase
        # ----------------
        model.train()
        running_loss = 0.0
        running_correct = 0
        total_samples_train = 0

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            batch_size_curr = y.size(0)
            total_samples_train += batch_size_curr

            outputs = model(X).float()
            loss = loss_fn(outputs, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * batch_size_curr
            running_correct += (outputs.argmax(dim=1) == y).sum().item()

        train_loss = running_loss / total_samples_train
        train_acc = (running_correct / total_samples_train) * 100

        # ----------------
        # Validation Phase
        # ----------------
        model.eval()
        val_loss_total = 0.0
        val_samples_total = 0
        correct_top1 = 0
        correct_top5 = 0

        with torch.inference_mode():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                batch_size_curr = y.size(0)
                val_samples_total += batch_size_curr

                outputs = model(X).float()
                loss = loss_fn(outputs, y)
                val_loss_total += loss.item() * batch_size_curr

                _, pred_topk = outputs.topk(5, dim=1, largest=True, sorted=True)
                correct = pred_topk.eq(y.view(-1, 1).expand_as(pred_topk))

                correct_top1 += correct[:, :1].sum().item()
                correct_top5 += correct[:, :5].sum().item()

        val_loss = val_loss_total / val_samples_total
        top1_val_acc = (correct_top1 / val_samples_total) * 100
        top5_val_acc = (correct_top5 / val_samples_total) * 100

        # ----------------
        # Logging
        # ----------------
        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
        print(f"Val Loss: {val_loss:.4f} | Top-1 Val Acc: {top1_val_acc:.2f}% | Top-5 Val Acc: {top5_val_acc:.2f}%")

        train_loss_history.append(train_loss)
        val_loss_history.append(val_loss)
        train_acc_history.append(train_acc)
        val_top1_acc_history.append(top1_val_acc)
        val_top5_acc_history.append(top5_val_acc)

        # Save best model
        if top1_val_acc > best_top1:
            best_top1 = top1_val_acc
            best_model_wts = model.state_dict().copy()
            os.makedirs("results/checkpoints", exist_ok=True)
            torch.save(best_model_wts, f"results/checkpoints/{model_name}_best.pth")
            print(f"[✓] Saved best model (Top-1 = {best_top1:.2f}%)")

        scheduler.step()

    end_time = timer()
    total_train_time_sec = end_time - start_time

    # Save metrics CSV
    save_epoch_metrics_csv(
        model_name=model_name,
        train_loss_history=train_loss_history,
        val_loss_history=val_loss_history,
        train_acc_history=train_acc_history,
        val_top1_acc_history=val_top1_acc_history,
        val_top5_acc_history=val_top5_acc_history
    )

    # Append summary CSV
    append_model_summary(
        model_name=model_name,
        train_loss_history=train_loss_history,
        val_loss_history=val_loss_history,
        train_acc_history=train_acc_history,
        val_top1_acc_history=val_top1_acc_history,
        val_top5_acc_history=val_top5_acc_history,
        total_train_time_sec=total_train_time_sec,
        model=model,
        batch_size=batch_size,
        optimizer_type="Adam (first 30 epochs) + SGD (rest)",
        lr_schedule_desc="StepLR: Adam(step=10, gamma=0.1), SGD(step=30, gamma=0.1)",
        image_size=f"{image_size[0]}x{image_size[1]}",
        architecture_type=architecture_type
    )

    print_train_time(start_time, end_time, device)
    print(f"[✓] Training complete for {model_name}")

# %%
# Defining architecture of plain_34_layer_model

def make_block(in_channels, out_channels, num_convs, stride):
    layers = []

    # First conv in the block (with possible downsampling)
    layers.append(nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1))
    layers.append(nn.BatchNorm2d(out_channels))
    layers.append(nn.ReLU(inplace=True))

    # Remaining convs (stride=1)
    for _ in range(num_convs - 1):
        layers.append(nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1))
        layers.append(nn.BatchNorm2d(out_channels))
        layers.append(nn.ReLU(inplace=True))

    return layers

class PlainNet34(nn.Module):
    def __init__(self, num_classes):
        super(PlainNet34, self).__init__()

        layers = []

        # Initial layer
        layers += [
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        ]

        # conv2_x: 3 blocks = 6 convs
        layers += make_block(64, 64, num_convs=6, stride=1)

        # conv3_x: 4 blocks = 8 convs
        layers += make_block(64, 128, num_convs=8, stride=2)

        # conv4_x: 6 blocks = 12 convs
        layers += make_block(128, 256, num_convs=12, stride=2)

        # conv5_x: 3 blocks = 6 convs
        layers += make_block(256, 512, num_convs=6, stride=2)

        # Final layers
        layers += [
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(512, num_classes)
        ]

        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# %%
model = PlainNet34(num_classes=100).to(device)

# Defining loss function
loss_fn = nn.CrossEntropyLoss()

# Defining optimizers
optimizer_adam = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)
optimizer_sgd = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# Using learning rate schedulers 
scheduler_adam = torch.optim.lr_scheduler.StepLR(optimizer_adam, step_size=10, gamma=0.1)
scheduler_sgd = torch.optim.lr_scheduler.StepLR(optimizer_sgd, step_size=30, gamma=0.1)

train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_fn=loss_fn,
    optimizer_adam=optimizer_adam,
    optimizer_sgd=optimizer_sgd,
    scheduler_adam=scheduler_adam,
    scheduler_sgd=scheduler_sgd,
    epochs=100,
    batch_size=128,
    image_size=(64, 64),
    architecture_type="PlainNet34",
    model_name="PlainNet34_ImageNet100"
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100
# --------------------
# Train Loss: 4.3002 | Train Acc: 3.52%
# Val Loss: 4.0905 | Top-1 Val Acc: 5.52% | Top-5 Val Acc: 22.18%
# [✓] Saved best model (Top-1 = 5.52%)
#
# Epoch 2/100
# --------------------
# Train Loss: 4.0393 | Train Acc: 6.30%
# Val Loss: 3.9953 | Top-1 Val Acc: 6.54% | Top-5 Val Acc: 25.82%
# [✓] Saved best model (Top-1 = 6.54%)
#
# Epoch 3/100
# --------------------
# Train Loss: 3.9242 | Train Acc: 7.74%
# Val Loss: 4.0017 | Top-1 Val Acc: 6.36% | Top-5 Val Acc: 25.54%
#
# Epoch 4/100
# --------------------
# Train Loss: 3.7921 | Train Acc: 9.92%
# Val Loss: 3.7575 | Top-1 Val Acc: 10.36% | Top-5 Val Acc: 33.62%
# [✓] Saved best model (Top-1 = 10.36%)
#
# Epoch 5/100
# --------------------
# Train Loss: 3.7077 | Train Acc: 11.33%
# Val Loss: 3.7128 | Top-1 Val Acc: 11.56% | Top-5 Val Acc: 35.08%
# [✓] Saved best model (Top-1 = 11.56%)
#
# Epoch 6/100
# --------------------
# Train Loss: 3.6354 | Train Acc: 12.70%
# Val Loss: 3.6188 | Top-1 Val Acc: 12.58% | Top-5 Val Acc: 38.00%
# [✓] Saved best model (Top-1 = 12.58%)
#
# Epoch 7/100
# --------------------
# Train Loss: 3.5837 | Train Acc: 13.76%
# Val Loss: 3.7584 | Top-1 Val Acc: 10.62% | Top-5 Val Acc: 34.12%
#
# Epoch 8/100
# --------------------
# Train Loss: 3.5331 | Train Acc: 14.53%
# Val Loss: 3.5765 | Top-1 Val Acc: 14.20% | Top-5 Val Acc: 40.20%
# [✓] Saved best model (Top-1 = 14.20%)
#
# Epoch 9/100
# --------------------
# Train Loss: 3.5089 | Train Acc: 15.12%
# Val Loss: 3.5164 | Top-1 Val Acc: 14.70% | Top-5 Val Acc: 41.86%
# [✓] Saved best model (Top-1 = 14.70%)
#
# Epoch 10/100
# --------------------
# Train Loss: 3.4838 | Train Acc: 15.72%
# Val Loss: 3.4660 | Top-1 Val Acc: 15.98% | Top-5 Val Acc: 42.50%
# [✓] Saved best model (Top-1 = 15.98%)
#
# Epoch 11/100
# --------------------
# Train Loss: 3.3232 | Train Acc: 18.81%
# Val Loss: 3.2767 | Top-1 Val Acc: 19.76% | Top-5 Val Acc: 47.50%
# [✓] Saved best model (Top-1 = 19.76%)
#
# Epoch 12/100
# --------------------
# Train Loss: 3.2777 | Train Acc: 19.59%
# Val Loss: 3.2634 | Top-1 Val Acc: 19.88% | Top-5 Val Acc: 47.96%
# [✓] Saved best model (Top-1 = 19.88%)
#
# Epoch 13/100
# --------------------
# Train Loss: 3.2628 | Train Acc: 20.18%
# Val Loss: 3.2511 | Top-1 Val Acc: 19.98% | Top-5 Val Acc: 48.14%
# [✓] Saved best model (Top-1 = 19.98%)
#
# Epoch 14/100
# --------------------
# Train Loss: 3.2490 | Train Acc: 20.31%
# Val Loss: 3.2321 | Top-1 Val Acc: 20.70% | Top-5 Val Acc: 48.56%
# [✓] Saved best model (Top-1 = 20.70%)
#
# Epoch 15/100
# --------------------
# Train Loss: 3.2398 | Train Acc: 20.54%
# Val Loss: 3.2259 | Top-1 Val Acc: 20.92% | Top-5 Val Acc: 48.36%
# [✓] Saved best model (Top-1 = 20.92%)
#
# Epoch 16/100
# --------------------
# Train Loss: 3.2271 | Train Acc: 20.94%
# Val Loss: 3.2224 | Top-1 Val Acc: 20.90% | Top-5 Val Acc: 48.60%
#
# Epoch 17/100
# --------------------
# Train Loss: 3.2163 | Train Acc: 21.05%
# Val Loss: 3.2187 | Top-1 Val Acc: 21.12% | Top-5 Val Acc: 49.04%
# [✓] Saved best model (Top-1 = 21.12%)
#
# Epoch 18/100
# --------------------
# Train Loss: 3.2094 | Train Acc: 21.18%
# Val Loss: 3.2186 | Top-1 Val Acc: 20.50% | Top-5 Val Acc: 49.24%
#
# Epoch 19/100
# --------------------
# Train Loss: 3.2055 | Train Acc: 21.32%
# Val Loss: 3.2071 | Top-1 Val Acc: 21.26% | Top-5 Val Acc: 49.52%
# [✓] Saved best model (Top-1 = 21.26%)
#
# Epoch 20/100
# --------------------
# Train Loss: 3.1962 | Train Acc: 21.58%
# Val Loss: 3.1898 | Top-1 Val Acc: 21.18% | Top-5 Val Acc: 49.68%
#
# Epoch 21/100
# --------------------
# Train Loss: 3.1823 | Train Acc: 21.56%
# Val Loss: 3.1741 | Top-1 Val Acc: 22.04% | Top-5 Val Acc: 50.18%
# [✓] Saved best model (Top-1 = 22.04%)
#
# Epoch 22/100
# --------------------
# Train Loss: 3.1678 | Train Acc: 21.97%
# Val Loss: 3.1693 | Top-1 Val Acc: 21.98% | Top-5 Val Acc: 50.40%
#
# Epoch 23/100
# --------------------
# Train Loss: 3.1711 | Train Acc: 22.06%
# Val Loss: 3.1705 | Top-1 Val Acc: 22.04% | Top-5 Val Acc: 50.30%
#
# Epoch 24/100
# --------------------
# Train Loss: 3.1688 | Train Acc: 22.00%
# Val Loss: 3.1698 | Top-1 Val Acc: 21.86% | Top-5 Val Acc: 49.90%
#
# Epoch 25/100
# --------------------
# Train Loss: 3.1677 | Train Acc: 22.11%
# Val Loss: 3.1748 | Top-1 Val Acc: 21.64% | Top-5 Val Acc: 50.38%
#
# Epoch 26/100
# --------------------
# Train Loss: 3.1678 | Train Acc: 22.00%
# Val Loss: 3.1765 | Top-1 Val Acc: 22.30% | Top-5 Val Acc: 50.54%
# [✓] Saved best model (Top-1 = 22.30%)
#
# Epoch 27/100
# --------------------
# Train Loss: 3.1622 | Train Acc: 22.17%
# Val Loss: 3.1677 | Top-1 Val Acc: 22.44% | Top-5 Val Acc: 50.76%
# [✓] Saved best model (Top-1 = 22.44%)
#
# Epoch 28/100
# --------------------
# Train Loss: 3.1649 | Train Acc: 22.05%
# Val Loss: 3.1693 | Top-1 Val Acc: 21.90% | Top-5 Val Acc: 50.26%
#
# Epoch 29/100
# --------------------
# Train Loss: 3.1631 | Train Acc: 22.24%
# Val Loss: 3.1682 | Top-1 Val Acc: 21.92% | Top-5 Val Acc: 50.60%
#
# Epoch 30/100
# --------------------
# Train Loss: 3.1568 | Train Acc: 22.47%
# Val Loss: 3.1691 | Top-1 Val Acc: 22.12% | Top-5 Val Acc: 50.32%
#
# Epoch 31/100
# --------------------
# Train Loss: 4.1693 | Train Acc: 5.94%
# Val Loss: 4.0018 | Top-1 Val Acc: 7.68% | Top-5 Val Acc: 26.44%
#
# Epoch 32/100
# --------------------
# Train Loss: 3.8991 | Train Acc: 9.07%
# Val Loss: 3.7855 | Top-1 Val Acc: 11.00% | Top-5 Val Acc: 33.24%
#
# Epoch 33/100
# --------------------
# Train Loss: 3.8514 | Train Acc: 9.73%
# Val Loss: 3.9130 | Top-1 Val Acc: 8.98% | Top-5 Val Acc: 30.50%
#
# Epoch 34/100
# --------------------
# Train Loss: 3.7866 | Train Acc: 10.62%
# Val Loss: 3.7714 | Top-1 Val Acc: 10.82% | Top-5 Val Acc: 33.38%
#
# Epoch 35/100
# --------------------
# Train Loss: 3.7845 | Train Acc: 10.75%
# Val Loss: 3.7138 | Top-1 Val Acc: 12.12% | Top-5 Val Acc: 35.62%
#
# Epoch 36/100
# --------------------
# Train Loss: 3.7218 | Train Acc: 11.85%
# Val Loss: 3.8102 | Top-1 Val Acc: 10.12% | Top-5 Val Acc: 32.68%
#
# Epoch 37/100
# --------------------
# Train Loss: 3.7204 | Train Acc: 11.76%
# Val Loss: 3.6485 | Top-1 Val Acc: 13.26% | Top-5 Val Acc: 37.96%
#
# Epoch 38/100
# --------------------
# Train Loss: 3.7010 | Train Acc: 12.16%
# Val Loss: 3.8295 | Top-1 Val Acc: 10.08% | Top-5 Val Acc: 31.80%
#
# Epoch 39/100
# --------------------
# Train Loss: 3.7321 | Train Acc: 11.81%
# Val Loss: 3.8727 | Top-1 Val Acc: 9.84% | Top-5 Val Acc: 30.30%
#
# Epoch 40/100
# --------------------
# Train Loss: 3.7843 | Train Acc: 10.90%
# Val Loss: 3.7302 | Top-1 Val Acc: 12.02% | Top-5 Val Acc: 35.04%
#
# Epoch 41/100
# --------------------
# Train Loss: 3.7139 | Train Acc: 11.79%
# Val Loss: 3.9849 | Top-1 Val Acc: 7.72% | Top-5 Val Acc: 25.78%
#
# Epoch 42/100
# --------------------
# Train Loss: 3.7684 | Train Acc: 10.86%
# Val Loss: 3.7049 | Top-1 Val Acc: 11.74% | Top-5 Val Acc: 34.84%
#
# Epoch 43/100
# --------------------
# Train Loss: 3.7104 | Train Acc: 11.93%
# Val Loss: 3.6679 | Top-1 Val Acc: 12.50% | Top-5 Val Acc: 37.18%
#
# Epoch 44/100
# --------------------
# Train Loss: 3.7096 | Train Acc: 11.63%
# Val Loss: 3.7008 | Top-1 Val Acc: 11.86% | Top-5 Val Acc: 36.08%
#
# Epoch 45/100
# --------------------
# Train Loss: 3.7096 | Train Acc: 11.77%
# Val Loss: 3.6763 | Top-1 Val Acc: 12.44% | Top-5 Val Acc: 37.02%
#
# Epoch 46/100
# --------------------
# Train Loss: 3.6759 | Train Acc: 12.35%
# Val Loss: 3.6859 | Top-1 Val Acc: 11.98% | Top-5 Val Acc: 35.92%
#
# Epoch 47/100
# --------------------
# Train Loss: 3.7203 | Train Acc: 11.67%
# Val Loss: 4.0666 | Top-1 Val Acc: 8.12% | Top-5 Val Acc: 25.76%
#
# Epoch 48/100
# --------------------
# Train Loss: 3.7140 | Train Acc: 11.80%
# Val Loss: 3.8486 | Top-1 Val Acc: 10.08% | Top-5 Val Acc: 32.72%
#
# Epoch 49/100
# --------------------
# Train Loss: 3.7010 | Train Acc: 11.96%
# Val Loss: 3.7226 | Top-1 Val Acc: 11.66% | Top-5 Val Acc: 35.02%
#
# Epoch 50/100
# --------------------
# Train Loss: 3.7000 | Train Acc: 12.00%
# Val Loss: 3.8199 | Top-1 Val Acc: 9.92% | Top-5 Val Acc: 31.66%
#
# Epoch 51/100
# --------------------
# Train Loss: 3.6758 | Train Acc: 12.34%
# Val Loss: 3.9124 | Top-1 Val Acc: 8.80% | Top-5 Val Acc: 31.44%
#
# Epoch 52/100
# --------------------
# Train Loss: 3.7089 | Train Acc: 11.92%
# Val Loss: 3.9007 | Top-1 Val Acc: 9.76% | Top-5 Val Acc: 30.06%
#
# Epoch 53/100
# --------------------
# Train Loss: 3.7038 | Train Acc: 11.91%
# Val Loss: 3.7044 | Top-1 Val Acc: 11.84% | Top-5 Val Acc: 35.44%
#
# Epoch 54/100
# --------------------
# Train Loss: 3.6842 | Train Acc: 12.32%
# Val Loss: 3.7519 | Top-1 Val Acc: 11.22% | Top-5 Val Acc: 34.16%
#
# Epoch 55/100
# --------------------
# Train Loss: 3.7258 | Train Acc: 11.77%
# Val Loss: 3.7514 | Top-1 Val Acc: 11.96% | Top-5 Val Acc: 34.90%
#
# Epoch 56/100
# --------------------
# Train Loss: 3.6935 | Train Acc: 12.39%
# Val Loss: 3.7041 | Top-1 Val Acc: 12.78% | Top-5 Val Acc: 36.22%
#
# Epoch 57/100
# --------------------
# Train Loss: 3.7212 | Train Acc: 11.68%
# Val Loss: 3.7565 | Top-1 Val Acc: 11.36% | Top-5 Val Acc: 33.78%
#
# Epoch 58/100
# --------------------
# Train Loss: 3.6890 | Train Acc: 12.17%
# Val Loss: 3.6365 | Top-1 Val Acc: 13.20% | Top-5 Val Acc: 37.50%
#
# Epoch 59/100
# --------------------
# Train Loss: 3.7541 | Train Acc: 11.40%
# Val Loss: 3.8310 | Top-1 Val Acc: 9.30% | Top-5 Val Acc: 31.26%
#
# Epoch 60/100
# --------------------
# Train Loss: 3.7296 | Train Acc: 11.46%
# Val Loss: 3.7132 | Top-1 Val Acc: 11.94% | Top-5 Val Acc: 35.32%
#
# Epoch 61/100
# --------------------
# Train Loss: 3.5435 | Train Acc: 14.50%
# Val Loss: 3.5159 | Top-1 Val Acc: 15.12% | Top-5 Val Acc: 40.24%
#
# Epoch 62/100
# --------------------
# Train Loss: 3.4880 | Train Acc: 15.50%
# Val Loss: 3.4815 | Top-1 Val Acc: 15.42% | Top-5 Val Acc: 41.34%
#
# Epoch 63/100
# --------------------
# Train Loss: 3.4606 | Train Acc: 15.85%
# Val Loss: 3.4625 | Top-1 Val Acc: 15.84% | Top-5 Val Acc: 42.12%
#
# Epoch 64/100
# --------------------
# Train Loss: 3.4463 | Train Acc: 16.14%
# Val Loss: 3.4135 | Top-1 Val Acc: 16.44% | Top-5 Val Acc: 43.34%
#
# Epoch 65/100
# --------------------
# Train Loss: 3.4213 | Train Acc: 16.57%
# Val Loss: 3.4078 | Top-1 Val Acc: 16.94% | Top-5 Val Acc: 43.78%
#
# Epoch 66/100
# --------------------
# Train Loss: 3.4114 | Train Acc: 16.77%
# Val Loss: 3.3861 | Top-1 Val Acc: 17.06% | Top-5 Val Acc: 44.56%
#
# Epoch 67/100
# --------------------
# Train Loss: 3.3931 | Train Acc: 17.10%
# Val Loss: 3.4144 | Top-1 Val Acc: 17.06% | Top-5 Val Acc: 43.68%
#
# Epoch 68/100
# --------------------
# Train Loss: 3.3800 | Train Acc: 17.45%
# Val Loss: 3.3793 | Top-1 Val Acc: 17.22% | Top-5 Val Acc: 45.12%
#
# Epoch 69/100
# --------------------
# Train Loss: 3.3702 | Train Acc: 17.51%
# Val Loss: 3.3575 | Top-1 Val Acc: 17.52% | Top-5 Val Acc: 45.36%
#
# Epoch 70/100
# --------------------
# Train Loss: 3.3729 | Train Acc: 17.72%
# Val Loss: 3.3587 | Top-1 Val Acc: 17.86% | Top-5 Val Acc: 45.50%
#
# Epoch 71/100
# --------------------
# Train Loss: 3.3665 | Train Acc: 17.59%
# Val Loss: 3.3627 | Top-1 Val Acc: 17.88% | Top-5 Val Acc: 45.06%
#
# Epoch 72/100
# --------------------
# Train Loss: 3.3635 | Train Acc: 17.90%
# Val Loss: 3.3860 | Top-1 Val Acc: 18.10% | Top-5 Val Acc: 44.16%
#
# Epoch 73/100
# --------------------
# Train Loss: 3.3849 | Train Acc: 17.40%
# Val Loss: 3.3727 | Top-1 Val Acc: 17.28% | Top-5 Val Acc: 44.94%
#
# Epoch 74/100
# --------------------
# Train Loss: 3.3545 | Train Acc: 17.97%
# Val Loss: 3.4699 | Top-1 Val Acc: 16.26% | Top-5 Val Acc: 42.32%
#
# Epoch 75/100
# --------------------
# Train Loss: 3.4115 | Train Acc: 17.21%
# Val Loss: 3.3426 | Top-1 Val Acc: 18.22% | Top-5 Val Acc: 45.78%
#
# Epoch 76/100
# --------------------
# Train Loss: 3.3483 | Train Acc: 18.21%
# Val Loss: 3.3529 | Top-1 Val Acc: 18.88% | Top-5 Val Acc: 45.66%
#
# Epoch 77/100
# --------------------
# Train Loss: 3.3425 | Train Acc: 18.29%
# Val Loss: 3.3145 | Top-1 Val Acc: 19.30% | Top-5 Val Acc: 46.08%
#
# Epoch 78/100
# --------------------
# Train Loss: 3.3341 | Train Acc: 18.53%
# Val Loss: 3.3849 | Top-1 Val Acc: 18.40% | Top-5 Val Acc: 44.80%
#
# Epoch 79/100
# --------------------
# Train Loss: 3.3879 | Train Acc: 17.64%
# Val Loss: 3.3476 | Top-1 Val Acc: 19.12% | Top-5 Val Acc: 45.94%
#
# Epoch 80/100
# --------------------
# Train Loss: 3.3384 | Train Acc: 18.47%
# Val Loss: 3.3714 | Top-1 Val Acc: 18.04% | Top-5 Val Acc: 44.80%
#
# Epoch 81/100
# --------------------
# Train Loss: 3.3461 | Train Acc: 18.22%
# Val Loss: 3.3905 | Top-1 Val Acc: 18.04% | Top-5 Val Acc: 43.52%
#
# Epoch 82/100
# --------------------
# Train Loss: 3.3409 | Train Acc: 18.33%
# Val Loss: 3.3577 | Top-1 Val Acc: 17.54% | Top-5 Val Acc: 44.94%
#
# Epoch 83/100
# --------------------
# Train Loss: 3.3666 | Train Acc: 17.88%
# Val Loss: 3.5699 | Top-1 Val Acc: 14.94% | Top-5 Val Acc: 39.50%
#
# Epoch 84/100
# --------------------
# Train Loss: 3.3431 | Train Acc: 18.39%
# Val Loss: 3.2921 | Top-1 Val Acc: 19.12% | Top-5 Val Acc: 46.28%
#
# Epoch 85/100
# --------------------
# Train Loss: 3.3534 | Train Acc: 18.31%
# Val Loss: 3.3220 | Top-1 Val Acc: 19.26% | Top-5 Val Acc: 45.80%
#
# Epoch 86/100
# --------------------
# Train Loss: 3.3311 | Train Acc: 18.59%
# Val Loss: 3.3085 | Top-1 Val Acc: 18.14% | Top-5 Val Acc: 46.04%
#
# Epoch 87/100
# --------------------
# Train Loss: 3.3341 | Train Acc: 18.68%
# Val Loss: 3.2838 | Top-1 Val Acc: 19.58% | Top-5 Val Acc: 46.80%
#
# Epoch 88/100
# --------------------
# Train Loss: 3.3068 | Train Acc: 19.02%
# Val Loss: 3.2990 | Top-1 Val Acc: 19.26% | Top-5 Val Acc: 47.02%
#
# Epoch 89/100
# --------------------
# Train Loss: 3.3155 | Train Acc: 18.81%
# Val Loss: 3.3491 | Top-1 Val Acc: 17.86% | Top-5 Val Acc: 44.92%
#
# Epoch 90/100
# --------------------
# Train Loss: 3.3631 | Train Acc: 18.01%
# Val Loss: 3.3961 | Top-1 Val Acc: 17.28% | Top-5 Val Acc: 43.50%
#
# Epoch 91/100
# --------------------
# Train Loss: 3.3299 | Train Acc: 18.61%
# Val Loss: 3.3055 | Top-1 Val Acc: 19.12% | Top-5 Val Acc: 46.48%
#
# Epoch 92/100
# --------------------
# Train Loss: 3.2762 | Train Acc: 19.44%
# Val Loss: 3.2657 | Top-1 Val Acc: 19.46% | Top-5 Val Acc: 47.66%
#
# Epoch 93/100
# --------------------
# Train Loss: 3.2485 | Train Acc: 19.94%
# Val Loss: 3.2585 | Top-1 Val Acc: 19.84% | Top-5 Val Acc: 47.36%
#
# Epoch 94/100
# --------------------
# Train Loss: 3.2276 | Train Acc: 20.51%
# Val Loss: 3.2296 | Top-1 Val Acc: 20.22% | Top-5 Val Acc: 48.36%
#
# Epoch 95/100
# --------------------
# Train Loss: 3.2194 | Train Acc: 20.57%
# Val Loss: 3.2352 | Top-1 Val Acc: 20.60% | Top-5 Val Acc: 48.46%
#
# Epoch 96/100
# --------------------
# Train Loss: 3.2182 | Train Acc: 20.61%
# Val Loss: 3.2224 | Top-1 Val Acc: 20.80% | Top-5 Val Acc: 48.32%
#
# Epoch 97/100
# --------------------
# Train Loss: 3.2124 | Train Acc: 20.78%
# Val Loss: 3.2060 | Top-1 Val Acc: 20.78% | Top-5 Val Acc: 49.00%
#
# Epoch 98/100
# --------------------
# Train Loss: 3.2021 | Train Acc: 20.98%
# Val Loss: 3.2100 | Top-1 Val Acc: 20.80% | Top-5 Val Acc: 48.54%
#
# Epoch 99/100
# --------------------
# Train Loss: 3.1984 | Train Acc: 21.07%
# Val Loss: 3.2147 | Top-1 Val Acc: 21.08% | Top-5 Val Acc: 48.72%
#
# Epoch 100/100
# --------------------
# Train Loss: 3.1961 | Train Acc: 21.02%
# Val Loss: 3.2048 | Top-1 Val Acc: 20.74% | Top-5 Val Acc: 48.88%
# [✓] Saved epoch metrics to results/per_model_logs/PlainNet34_ImageNet100_metrics.csv
# [✓] Appended model summary to results/summary/final_model_comparison.csv
# Train time on cuda : 15493.392 seconds
# [✓] Training complete for PlainNet34_ImageNet100
